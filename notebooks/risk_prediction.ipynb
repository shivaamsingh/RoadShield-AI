# %%
import pandas as pd

df = pd.read_csv("../data/indian_roads_dataset.csv")

# %%
df["risk_score"].describe()
# Out:
# count    20000.000000
# mean         0.437585
# std          0.218130
# min          0.100000
# 25%          0.250000
# 50%          0.450000
# 75%          0.600000
# max          1.000000
# Name: risk_score, dtype: float64

# %%
df["risk_score"].hist()
# Out:
# <Axes: >
